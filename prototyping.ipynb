# %%
#just to prototype the ideas

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
device = torch.device("mps" if torch.mps.is_available() else "cpu")  #from now on, will utilize the GPU
torch.mps.is_available() #is indeed available
# Out:
# True

# %%
#working with shakesperian texts dataset for this egs, but can be extended to any text dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
#dataset of all the work of shakespear
# Out:
# --2025-01-03 09:54:53--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.1’
#
# input.txt.1         100%[===================>]   1.06M  6.29MB/s    in 0.2s
#
# 2025-01-03 09:54:53 (6.29 MB/s) - ‘input.txt.1’ saved [1115394/1115394]

# %%
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
print("len of text: ", len(text))  #approx as 1.2M characters
# Out:
# len of text:  1115394

# %%
print(text[:1000])
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.

# %%
#get all the unique chars used in the text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(f"vocabulary size: {vocab_size}")
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocabulary size: 65

# %%
#creating a mapping
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[ch] for ch in s]  #take in a string, give out its integer representation
decode = lambda list: ''.join([itos[i] for i in list] ) #take in a list of integers, give out its chars

# %%
encode("hello shakespear")
# Out:
# [46, 43, 50, 50, 53, 1, 57, 46, 39, 49, 43, 57, 54, 43, 39, 56]

# %%
data = torch.tensor(encode(text), dtype=torch.long, device=device) 
print(data.shape, data.dtype)
print(data[:100])
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59], device='mps:0')

# %%
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

# %%
#in transformers, we work with context sizes from 1 all the way till block_size(whatever that is)
#previously in n-gram neural nets, we used to work with fixed context sizes, but this is not the case
#here, and it is also advantageous, as the model learns to work with different context sizes

block_size = 8
x = train_data[:block_size]
y = train_data[1:block_size+1]

for t in range(block_size):  #here t is the time step, as we work with each of the sub contexts
    #during training and that is done consecutively, over time, however there is another dimension 
    #to it, which is the batch dim, where the samples of the batch are handled in parallel
    context = x[:t+1]
    target = y[t]
    print(f"for context {context} what follows is {target}")
# Out:
# for context tensor([18], device='mps:0') what follows is 47
# for context tensor([18, 47], device='mps:0') what follows is 56
# for context tensor([18, 47, 56], device='mps:0') what follows is 57
# for context tensor([18, 47, 56, 57], device='mps:0') what follows is 58
# for context tensor([18, 47, 56, 57, 58], device='mps:0') what follows is 1
# for context tensor([18, 47, 56, 57, 58,  1], device='mps:0') what follows is 15
# for context tensor([18, 47, 56, 57, 58,  1, 15], device='mps:0') what follows is 47
# for context tensor([18, 47, 56, 57, 58,  1, 15, 47], device='mps:0') what follows is 58

# %%
#introducing the batch dim
batch_size = 4

def get_batch(name):
    data = train_data if name == 'train' else val_data
    ix = torch.randint(0, data.size(0) - block_size, (batch_size,))
    context = torch.stack([data[i: i+block_size] for i in ix])
    target = torch.stack([data[i+1: i+1+block_size] for i in ix])
    return context, target

xb, yb = get_batch('train')
print(xb.shape)
print("inputs: ", xb)
print(yb.shape)
print("targets: ", yb)


#going through the batch and time dim 
for b in range(batch_size):
    for t in range(block_size):
        print(f"batch {b} context {xb[b, :t+1]} target {yb[b, t]}")
# Out:
# torch.Size([4, 8])
# inputs:  tensor([[51,  1, 46, 47, 57,  8,  0,  0],
#         [ 1, 63, 53, 59,  1, 50, 43, 39],
#         [43, 47, 56,  1, 57, 59, 51, 51],
#         [43, 57, 58, 63,  1, 46, 43,  1]], device='mps:0')
# torch.Size([4, 8])
# targets:  tensor([[ 1, 46, 47, 57,  8,  0,  0, 37],
#         [63, 53, 59,  1, 50, 43, 39, 52],
#         [47, 56,  1, 57, 59, 51, 51, 43],
#         [57, 58, 63,  1, 46, 43,  1, 41]], device='mps:0')
# batch 0 context tensor([51], device='mps:0') target 1
# batch 0 context tensor([51,  1], device='mps:0') target 46
# batch 0 context tensor([51,  1, 46], device='mps:0') target 47
# batch 0 context tensor([51,  1, 46, 47], device='mps:0') target 57
# batch 0 context tensor([51,  1, 46, 47, 57], device='mps:0') target 8
# batch 0 context tensor([51,  1, 46, 47, 57,  8], device='mps:0') target 0
# batch 0 context tensor([51,  1, 46, 47, 57,  8,  0], device='mps:0') target 0
# batch 0 context tensor([51,  1, 46, 47, 57,  8,  0,  0], device='mps:0') target 37
# batch 1 context tensor([1], device='mps:0') target 63
# batch 1 context tensor([ 1, 63], device='mps:0') target 53
# batch 1 context tensor([ 1, 63, 53], device='mps:0') target 59
# batch 1 context tensor([ 1, 63, 53, 59], device='mps:0') target 1
# batch 1 context tensor([ 1, 63, 53, 59,  1], device='mps:0') target 50
# batch 1 context tensor([ 1, 63, 53, 59,  1, 50], device='mps:0') target 43
# batch 1 context tensor([ 1, 63, 53, 59,  1, 50, 43], device='mps:0') target 39
# batch 1 context tensor([ 1, 63, 53, 59,  1, 50, 43, 39], device='mps:0') target 52
# batch 2 context tensor([43], device='mps:0') target 47
# batch 2 context tensor([43, 47], device='mps:0') target 56
# batch 2 context tensor([43, 47, 56], device='mps:0') target 1
# batch 2 context tensor([43, 47, 56,  1], device='mps:0') target 57
# batch 2 context tensor([43, 47, 56,  1, 57], device='mps:0') target 59
# batch 2 context tensor([43, 47, 56,  1, 57, 59], device='mps:0') target 51
# batch 2 context tensor([43, 47, 56,  1, 57, 59, 51], device='mps:0') target 51
# batch 2 context tensor([43, 47, 56,  1, 57, 59, 51, 51], device='mps:0') target 43
# batch 3 context tensor([43], device='mps:0') target 57
# batch 3 context tensor([43, 57], device='mps:0') target 58
# batch 3 context tensor([43, 57, 58], device='mps:0') target 63
# batch 3 context tensor([43, 57, 58, 63], device='mps:0') target 1
# batch 3 context tensor([43, 57, 58, 63,  1], device='mps:0') target 46
# batch 3 context tensor([43, 57, 58, 63,  1, 46], device='mps:0') target 43
# batch 3 context tensor([43, 57, 58, 63,  1, 46, 43], device='mps:0') target 1
# batch 3 context tensor([43, 57, 58, 63,  1, 46, 43,  1], device='mps:0') target 41

# %%
print(xb)
# Out:
# tensor([[51,  1, 46, 47, 57,  8,  0,  0],
#         [ 1, 63, 53, 59,  1, 50, 43, 39],
#         [43, 47, 56,  1, 57, 59, 51, 51],
#         [43, 57, 58, 63,  1, 46, 43,  1]], device='mps:0')

# %%
print(yb)
# Out:
# tensor([[ 1, 46, 47, 57,  8,  0,  0, 37],
#         [63, 53, 59,  1, 50, 43, 39, 52],
#         [47, 56,  1, 57, 59, 51, 51, 43],
#         [57, 58, 63,  1, 46, 43,  1, 41]], device='mps:0')

# %%
#again, starting off with the bigram count model, again this is similar to the count model(neural net)
#which can learn too, where recall that had only the input and output layer and no hidden 
#layers, this is something similar too, where the embedding layer is essemtially
#the output layer, since it has 65 neurons which match the vocab size, so it can be 
#thought of as the logits/output layer, and hence it makes sense that we calculate the loss
#based on this directly

torch.manual_seed(1337)

class BigramLanguageModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)   #embedding dim is of
        #vocab size

    def forward(self, idx, targets=None):
        #idx is (B, T) and targets is also (B, T)
        logits = self.token_embedding_table(idx)  # (B, T, C)
        self.B, self.T, self.C = logits.shape
        logits = logits.view(self.B*self.T, self.C)
        
        if targets is None:
            loss = None
        else:
            targets = targets.view(self.B*self.T)
            loss = F.cross_entropy(logits, targets) #but for loss, it want it in form (B, C, T)
        return logits, loss
    
    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            logits, loss = self(idx)  #calls forward method
            logits = logits.view(self.B, self.T, self.C)[:, -1, :]  #(B, C)
            probs = F.softmax(logits, dim=-1)  #(B, C)
            idx_next = torch.multinomial(probs, num_samples=1)  # (B, 1)
            #append the sampled char to the idx
            print(decode([idx_next.view(-1)[0].item()]), end="")
            idx = torch.cat([idx, idx_next], dim=1)  #(B, T+1)
        return idx
    
m =  BigramLanguageModel(vocab_size).to(device)  #passing the whole class to device, that way 
#individual tensors will be moved to the device as well
print(xb.shape)
logits, loss = m(xb, yb)  #calls the forawrd method as this class is a subclass of nn.Module and
#calling an instance of nn.module calls the .__call__() method which in turn calls the forward method
print(logits)
print("\n")
l = logits.view(m.B, m.T, m.C)[:, -1, :]
print(l)
print(l.shape)
print(loss)
# Out:
# torch.Size([4, 8])
# tensor([[-1.4177,  0.8682, -0.9121,  ..., -0.6264,  1.2195,  0.2068],
#         [ 0.5978, -0.0514, -0.0646,  ..., -1.4649, -2.0555,  1.8275],
#         [ 1.0901,  0.2170, -2.9996,  ..., -0.5472, -0.8017,  0.7761],
#         ...,
#         [ 1.0901,  0.2170, -2.9996,  ..., -0.5472, -0.8017,  0.7761],
#         [ 0.3323, -0.0872, -0.7470,  ..., -0.6716, -0.9572, -0.9594],
#         [ 0.5978, -0.0514, -0.0646,  ..., -1.4649, -2.0555,  1.8275]],
#        device='mps:0', grad_fn=<ViewBackward0>)
#
#
# tensor([[ 1.8077e-01, -6.9988e-02, -3.5962e-01, -9.1520e-01,  6.2577e-01,
#           2.5510e-02,  9.5451e-01,  6.4349e-02,  3.6115e-01,  1.1679e+00,
#          -1.3499e+00, -5.1018e-01,  2.3596e-01, -2.3978e-01, -9.2111e-01,
#           1.5433e+00,  1.3488e+00, -1.3964e-01,  2.8580e-01,  9.6512e-01,
#          -2.0371e+00,  4.9314e-01,  1.4870e+00,  5.9103e-01,  1.2603e-01,
#          -1.5627e+00, -1.1601e+00, -3.3484e-01,  4.4777e-01, -8.0164e-01,
#           1.5236e+00,  2.5086e+00, -6.6310e-01, -2.5128e-01,  1.0101e+00,
#           1.2155e-01,  1.5840e-01,  1.1340e+00, -1.1539e+00, -2.9840e-01,
#          -5.0754e-01, -9.2392e-01,  5.4671e-01, -1.4948e+00, -1.2057e+00,
#           5.7182e-01, -5.9735e-01, -6.9368e-01,  1.6455e+00, -8.0299e-01,
#           1.3514e+00, -2.7592e-01, -1.5108e+00,  2.1048e+00,  2.7630e+00,
#          -1.7465e+00,  1.4516e+00, -1.5103e+00,  8.2115e-01, -2.1153e-01,
#           7.7890e-01,  1.5333e+00,  1.6097e+00, -4.0323e-01, -8.3447e-01],
#         [ 1.1513e+00,  1.0539e+00,  3.4105e+00, -9.6206e-01, -1.1720e+00,
#           5.9532e-01, -4.0978e-01,  1.4256e+00, -1.2171e+00, -1.6845e+00,
#           5.3848e-01,  1.8967e+00, -2.7450e-01,  2.7868e-01, -6.4734e-01,
#          -2.6276e+00, -1.3731e+00, -1.2415e+00,  7.0759e-01, -4.9464e-01,
#           1.1809e+00,  5.4237e-01, -8.5781e-01,  5.1982e-01,  1.5089e-01,
#          -3.9927e-02,  1.0038e+00, -1.1435e+00,  1.8040e+00, -2.9009e-02,
#          -8.1313e-01,  9.0933e-01, -1.1375e+00,  5.1402e-01, -4.8947e-01,
#          -8.0550e-02,  9.1511e-01, -5.4810e-01,  1.1071e+00, -3.5050e-01,
#           6.6735e-01, -8.9356e-02,  2.7234e-01,  6.0345e-01,  2.3188e-01,
#           1.5473e+00, -6.8860e-01, -4.4137e-01,  1.2790e+00, -9.9592e-01,
#          -4.3626e-01, -8.7003e-01, -5.3829e-02,  1.1496e+00,  1.0411e+00,
#           5.8017e-02, -1.6868e+00,  4.0054e-01,  1.0880e+00, -4.8284e-01,
#          -7.0947e-02,  1.0966e+00, -5.6861e-01,  9.0792e-01, -1.7011e-01],
#         [-1.4177e+00,  8.6819e-01, -9.1207e-01,  1.5838e-01, -1.6181e+00,
#          -8.4517e-01,  8.1276e-01, -2.1116e+00, -1.1621e+00,  4.7431e-01,
#           3.1643e-01,  1.0056e+00, -9.1582e-01, -1.9572e+00,  5.5210e-02,
#           2.7064e-01, -1.5950e-01, -9.4920e-01, -3.4615e-01,  7.2554e-01,
#          -8.1084e-02,  1.1868e+00,  2.0059e+00, -1.6919e-01, -2.6943e-01,
#          -1.4600e+00,  1.3744e+00,  1.8214e-01, -5.6405e-01, -7.6338e-01,
#           7.6054e-01, -5.7714e-01, -8.2267e-01,  2.7618e-01,  8.1737e-01,
#          -7.7062e-01, -1.6287e+00, -1.2557e-01,  2.1198e+00,  5.9238e-01,
#           8.6997e-01,  1.0667e-02, -7.9374e-01, -4.7307e-01, -9.9546e-01,
#           1.3974e-01,  2.5155e-01, -8.9208e-01, -9.9399e-01, -1.5619e+00,
#           1.8046e-03, -4.8847e-01,  1.3973e+00, -8.1856e-01,  2.0498e-01,
#           1.2718e-01,  5.1120e-01,  6.5488e-01, -1.5950e-01,  1.1275e+00,
#           5.7560e-01, -7.4113e-01, -6.2638e-01,  1.2195e+00,  2.0684e-01],
#         [ 5.9780e-01, -5.1406e-02, -6.4559e-02, -4.9701e-01,  4.6576e-01,
#          -2.5726e-01, -1.0673e+00,  2.0089e+00, -5.3698e-01,  2.2280e-01,
#           6.9705e-01, -1.4267e+00,  9.0594e-01,  1.4459e-01,  2.2800e-01,
#           2.4900e+00, -1.2237e+00,  1.0107e+00,  5.5600e-01, -1.5935e+00,
#          -1.2706e+00,  6.9033e-01, -1.9614e-01,  3.4491e-01, -3.4189e-01,
#           4.7587e-01, -7.6634e-01, -4.1896e-01, -4.3699e-01, -1.0012e+00,
#          -4.0943e-01, -1.6669e+00, -1.3651e+00, -1.6552e-01,  9.6225e-01,
#           3.1549e-02, -7.4190e-01, -2.9779e-01,  1.7166e-02, -1.7722e-01,
#          -1.3343e-01,  2.9396e-01,  1.3850e+00,  1.2091e-01,  2.5418e+00,
#          -6.4046e-01, -1.9740e+00, -3.2957e-01,  7.9589e-03,  9.2623e-01,
#          -1.8846e+00,  1.6696e-01,  4.5862e-01, -1.7662e+00,  5.8599e-01,
#           1.7510e+00,  2.8072e-01,  3.1096e-01, -6.5376e-01, -6.5763e-01,
#           3.1845e-01, -5.4959e-01, -1.4649e+00, -2.0555e+00,  1.8275e+00]],
#        device='mps:0', grad_fn=<SliceBackward0>)
# torch.Size([4, 65])
# tensor(4.8612, device='mps:0', grad_fn=<NllLossBackward0>)

# %%
#the loss shld actually be -ln(1/65) which is 4.17

# %%
#generating text
m.generate(torch.zeros((1, 1), dtype=torch.long, device=device), 100)[0].tolist()
#works on batches, so the 0th index has to be indexed to
# Out:
# pr.lyV;KpYClyQR;RyFqfuEUjL-kq,SPyh
# G'zClLphj'Py BTF&gQ?yFMkQ?,mbnQLgRMnk&ofBL!?q-wc&yuCDylgC'Qhuq-gY
# [0,
#  54,
#  56,
#  8,
#  50,
#  63,
#  34,
#  11,
#  23,
#  54,
#  37,
#  15,
#  50,
#  63,
#  29,
#  30,
#  11,
#  30,
#  63,
#  18,
#  55,
#  44,
#  59,
#  17,
#  33,
#  48,
#  24,
#  7,
#  49,
#  55,
#  6,
#  31,
#  28,
#  63,
#  46,
#  0,
#  19,
#  5,
#  64,
#  15,
#  50,
#  24,
#  54,
#  46,
#  48,
#  5,
#  28,
#  63,
#  1,
#  14,
#  32,
#  18,
#  4,
#  45,
#  29,
#  12,
#  63,
#  18,
#  25,
#  49,
#  29,
#  12,
#  6,
#  51,
#  40,
#  52,
#  29,
#  24,
#  45,
#  30,
#  25,
#  52,
#  49,
#  4,
#  53,
#  44,
#  14,
#  24,
#  2,
#  12,
#  55,
#  7,
#  61,
#  41,
#  4,
#  63,
#  59,
#  15,
#  16,
#  63,
#  50,
#  45,
#  15,
#  5,
#  29,
#  46,
#  59,
#  55,
#  7,
#  45,
#  37]

# %%
#notice what we do here, wihtin generate method we call the forward method again and again, each time
#with an extended context and then we sample the dist from the last token, eventually, the history
#which is the context that came before will be used and then this approach will make more sense

# %%
#training this model now
optimiser = torch.optim.AdamW(m.parameters(), lr=1e-3)  #basically train the embedding layer, so
#as to get finer embeddings, and hence better predictions. Its the same as the two layer model for
#the count bigram model, where the weights which connected the input and output layer were trained, but
#here instead of the weights, the embeddings are trained

# %%
batch_size = 32
for steps in range(4000):

    #get a batch of data
    xb, yb = get_batch('train')

    #evaluate the loss
    logits, loss = m(xb, yb)

    #backprop
    optimiser.zero_grad(set_to_none=True)
    loss.backward()

    #update
    optimiser.step()

    print(loss);
# Out:
# tensor(4.6485, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6507, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7109, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7115, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7078, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6761, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6929, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7817, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.8193, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7402, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6960, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7699, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7788, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6514, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6445, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.8275, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7079, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7877, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6358, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6694, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7706, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6980, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6888, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7336, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6447, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6615, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6525, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7978, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6673, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.8019, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6777, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7393, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7681, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6637, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6660, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7945, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7079, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6955, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7849, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6422, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5648, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5635, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7708, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6270, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6385, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7168, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6498, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5812, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7059, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7175, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6571, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7142, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6579, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6304, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5770, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6460, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7058, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6821, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6655, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6888, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6125, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7709, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6826, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6512, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7369, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5979, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5198, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5899, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5425, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5972, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5614, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6133, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5952, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6202, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7212, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6880, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6353, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5758, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6757, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6603, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6541, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5728, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6435, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6595, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6828, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6617, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6434, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6330, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6780, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7646, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7797, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5708, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5762, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7329, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.7407, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6430, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5960, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6306, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6743, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6142, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4685, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5446, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6688, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6863, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5571, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6229, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6047, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5109, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6214, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6480, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5939, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5901, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6333, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4972, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6588, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6258, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5536, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4995, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5259, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5033, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5948, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5086, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5639, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5566, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5362, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5765, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4935, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5990, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6014, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6827, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6143, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5324, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5285, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6776, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5261, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6466, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5851, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4941, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5564, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5921, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5176, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5716, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5931, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4494, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5440, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4603, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5023, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4857, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5889, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5759, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5453, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5018, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5533, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5091, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3475, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5245, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5335, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6148, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5188, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5419, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4547, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5561, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5790, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5243, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5185, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6697, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6197, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4630, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6233, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5075, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4618, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5265, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5466, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5482, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5406, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5375, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5499, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4868, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5376, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5891, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3384, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4552, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.6129, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5782, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4626, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4602, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4275, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4906, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4700, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4582, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4838, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4735, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5250, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4810, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4512, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5169, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4841, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5260, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4951, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5136, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5905, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4595, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4649, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3944, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5136, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5561, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5732, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4735, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4212, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5013, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4393, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5736, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4387, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4873, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4392, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4507, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4440, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4882, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4289, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5420, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4604, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4411, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4728, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4276, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4489, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4566, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4347, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5009, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4366, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4579, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4245, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3255, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4875, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4090, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4064, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3258, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5409, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3280, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4248, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4802, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5409, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4626, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4934, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4444, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4536, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4997, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4380, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3480, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3611, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4319, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5402, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4134, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4422, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3675, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5474, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3951, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4158, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3966, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4900, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3193, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4546, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2862, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4060, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4388, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3043, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4604, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3439, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4314, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4610, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4596, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4254, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5732, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4229, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3577, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3734, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3665, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4339, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4069, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4002, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2661, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4197, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3835, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3160, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3783, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2545, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3233, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3752, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2914, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4133, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4597, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3506, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4640, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3373, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2223, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3597, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3065, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3171, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3374, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4195, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3445, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3253, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4141, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3820, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3797, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.5265, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3607, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3630, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3642, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2992, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4499, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4134, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3299, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3761, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4257, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3407, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3392, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3764, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3352, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3461, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3712, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3165, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3227, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3820, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3261, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3986, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4365, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3689, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3296, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2409, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3518, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3192, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3664, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3351, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2301, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2323, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3150, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2692, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2948, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3918, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3547, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3379, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2012, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2951, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3059, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2646, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2508, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3586, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2697, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2985, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3330, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2730, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3530, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2784, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2965, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2257, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3677, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2451, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3462, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3280, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2813, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2401, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2702, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3139, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3439, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3762, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2349, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2666, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3175, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2700, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2905, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2837, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2300, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2062, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2497, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2592, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1778, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2843, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2727, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2934, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3123, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2536, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2866, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3017, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2308, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2717, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1587, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2663, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2627, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1326, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3144, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2146, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2526, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2364, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2519, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2783, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2145, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2458, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3099, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2314, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2144, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1858, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2348, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2531, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2554, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2467, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1895, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2435, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1930, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1974, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2880, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2847, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2909, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2329, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2401, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1661, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3531, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2295, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1211, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2577, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2900, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2601, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1241, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2161, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2941, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2344, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2119, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2987, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1798, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2140, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2520, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2729, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1735, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2338, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1422, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1067, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2390, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2439, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2768, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.4057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1727, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2591, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2421, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2288, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2618, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3039, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1242, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1488, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2059, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1586, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2816, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2966, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1864, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3236, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2932, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2636, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1655, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1612, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1558, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2564, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1251, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1621, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2490, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2592, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1279, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2363, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1668, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1335, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1677, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2179, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1297, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2070, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1538, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2538, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1774, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1626, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1544, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1735, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2139, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2387, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2433, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1608, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1654, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2247, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1581, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1480, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2021, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1794, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1371, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1270, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1210, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1010, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1676, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1698, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1074, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2209, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2112, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2408, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1990, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0425, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1687, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1387, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2709, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1812, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1780, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1411, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1709, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0817, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2423, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0126, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0674, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1897, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0913, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1001, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1671, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1808, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1099, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0725, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1650, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.3003, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1180, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1514, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1601, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0604, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1594, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0507, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0505, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1408, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0672, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0810, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1273, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1639, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0425, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0201, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0905, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2595, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0635, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1627, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1290, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1528, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0931, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1305, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9905, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0993, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0877, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0670, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2298, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1127, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0978, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0639, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0644, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0336, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0563, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1214, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0735, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1214, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1875, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1499, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0428, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1289, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9915, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0658, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0897, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0206, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0121, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1513, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1798, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1123, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0376, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0203, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1426, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1311, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2397, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0830, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1355, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0451, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0156, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0024, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0063, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.2104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0335, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0919, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0969, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0938, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0532, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9871, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9712, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0141, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0494, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0383, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1418, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1205, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0069, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0956, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9631, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0913, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0546, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1753, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1104, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0234, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0621, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9758, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9615, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0499, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9935, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0167, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1358, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0852, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0877, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0378, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0653, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0078, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9917, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0672, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0194, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9947, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1337, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0495, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9854, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0176, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9980, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0116, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9175, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0992, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1054, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0093, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0274, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9755, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9862, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0813, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0674, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8556, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0589, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0454, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9543, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9680, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0050, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9700, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9371, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0835, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9206, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9815, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0086, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9779, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0747, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0634, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0222, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0302, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0180, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0220, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9780, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9209, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0037, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0733, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0579, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9682, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9954, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9503, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0149, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9002, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0559, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1072, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0784, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0637, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9654, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9603, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0305, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9409, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9543, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0295, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9579, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9660, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9593, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9130, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0707, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.1106, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0315, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9393, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8966, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9776, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0259, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9586, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9846, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9950, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0707, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9340, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9673, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9573, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9117, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9665, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9709, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9300, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9681, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9740, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9758, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9651, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8647, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9217, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0064, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9814, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9183, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9503, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9512, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9015, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9108, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8590, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9261, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9607, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9806, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0064, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8446, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8635, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9579, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9789, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0218, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9258, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8946, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8918, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8282, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9419, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9612, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8945, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8929, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8537, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8965, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9412, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9797, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0095, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9402, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8848, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8892, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8947, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9417, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.7878, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9220, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9209, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8993, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9953, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9719, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9566, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9360, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8881, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8430, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8978, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9111, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8709, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8934, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9235, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8904, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9514, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8563, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8027, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8927, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9627, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8220, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9449, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8278, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8761, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9469, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9606, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8250, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8818, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8703, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8339, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8754, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8876, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8821, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(4.0737, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.7967, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8218, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8926, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8558, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9200, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9145, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8315, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.8974, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(3.9882, device='mps:0', grad_fn=<NllLossBackward0>)
# ...
# tensor(2.7004, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7566, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6963, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6472, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6399, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7109, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6686, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7045, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6804, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7251, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7088, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6929, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7825, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6722, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7280, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7929, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5207, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5747, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6311, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6238, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6779, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5897, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7851, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6114, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6621, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6321, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7433, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7447, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7293, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6899, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6100, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6266, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6493, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5451, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6763, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7289, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6249, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6694, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7577, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6084, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6918, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6679, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6886, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.8584, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6362, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5556, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6701, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5733, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6467, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6706, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7670, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5930, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6097, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5894, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6612, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7269, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6571, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6729, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6955, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6202, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5645, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7552, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6849, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6701, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5687, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6687, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6235, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6740, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.8061, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6918, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6003, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6953, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5817, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5959, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6762, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7205, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6083, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5994, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6392, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6791, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6583, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6072, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5664, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7098, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6102, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6301, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7412, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.8091, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5502, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6185, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7561, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6953, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6951, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7041, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6513, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.8380, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5175, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7134, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6458, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7057, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6117, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7038, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7570, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6471, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6741, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6262, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6626, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7156, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5901, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7230, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5703, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6217, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6016, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6807, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6848, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7000, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6381, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6314, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7582, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6454, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7072, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6025, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6123, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7184, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5280, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6948, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6267, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6683, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6044, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6229, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6284, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7137, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.4776, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6769, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5728, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6992, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6435, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6957, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5204, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6020, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6892, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7374, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6307, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6668, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6370, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6261, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5178, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5986, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6131, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6005, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5539, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6066, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6345, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6777, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6483, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6875, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6599, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6748, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6737, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6881, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7366, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5915, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6632, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6919, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6824, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7281, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5889, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5631, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7159, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6370, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7448, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7497, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6619, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6571, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6105, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6952, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5539, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7753, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6437, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7405, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5130, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6154, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6551, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6722, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5994, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6055, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6565, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5521, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6811, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5885, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5766, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5963, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7289, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6381, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6450, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6773, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5729, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6187, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6394, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5607, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6439, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7145, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6250, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6898, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6508, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6480, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5938, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6810, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6580, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6649, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5345, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6560, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6310, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6102, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5779, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7775, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6765, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7286, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6060, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6258, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5621, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6080, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6066, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6211, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6046, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7002, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7130, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7205, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5254, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5978, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6421, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7498, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6583, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6584, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5949, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5640, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7513, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5951, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7171, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6258, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6053, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6029, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6260, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.8166, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7173, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5958, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6829, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6072, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6284, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6614, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6253, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6399, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6247, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.8030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6692, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6589, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6816, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5870, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5844, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.5965, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6728, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6699, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6030, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6923, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.6295, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7026, device='mps:0', grad_fn=<NllLossBackward0>)
# tensor(2.7440, device='mps:0', grad_fn=<NllLossBackward0>)

# %%
print(decode(m.generate(torch.zeros((1, 1), dtype=torch.long, device=device), 500)[0].tolist()))
# Out:
# HPayo in mppry way av IFooubT:$zDusickns bokthaNAl-hiNCL:
#
# p, ?w elgne? gaise fre lbustselow!'dcus; tom CUR:
# TIONTRF$I m hEUjurks,Singn itheLpha's oBy ogiy whe f, bad gien &ofBimatey &y cDWler'dsuq-isold arrayf
#
# INCy ck
# JXEENus!u!Bun mzmybalor:
# Bongmy!oe, d Vofatthindy st
# HBfqqUMy, mavyFathewkner3Xzo, T;ppmp!
# WHe d Y tDWhin IESYgin Thean apsts lathindKIO:
# BerineZQk IOLUEDzdj,
# KVjj$O'd Fe.F n IV:
# YoalupeqVO f keiA!UNpplitu t
# Tomyorerrof-prind ans COMg wo'henon-hu CU nd ypt?wilorUCK:CHAHATh yZveee

# %% [markdown]
# self-attention
#
# information only flows from previous tokens to the current ones, and the ones from the future cannot talk to the current token, and this is as we want to predict the future context, and getting any info
# from the future would not serve the purpose

# %%
#working with a toy egs to see what is meant 
torch.manual_seed(1337)

B, T, C = 4, 8, 2   # batch, time, channels
x = torch.randn(B, T, C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %%
#a very simple version of attention, where the embedding of tth token is the mean of all the tokens
#before it in the sample, and the mean is taken along the same dims 
xbow = torch.zeros((B, T, C))
for b in range(B):
    for t in range(T):
        xprev = x[b, :t+1]  #also including the embedding vector for the tth token 
        xbow[b, t] = torch.mean(xprev, dim=0)

# %%
x[0]
# Out:
# tensor([[ 0.1808, -0.0700],
#         [-0.3596, -0.9152],
#         [ 0.6258,  0.0255],
#         [ 0.9545,  0.0643],
#         [ 0.3612,  1.1679],
#         [-1.3499, -0.5102],
#         [ 0.2360, -0.2398],
#         [-0.9211,  1.5433]])

# %%
xbow[0]
# Out:
# tensor([[ 0.1808, -0.0700],
#         [-0.0894, -0.4926],
#         [ 0.1490, -0.3199],
#         [ 0.3504, -0.2238],
#         [ 0.3525,  0.0545],
#         [ 0.0688, -0.0396],
#         [ 0.0927, -0.0682],
#         [-0.0341,  0.1332]])

# %%
#so we see that since the 0th token doesnt really have any context before it, its vector after
#self-attention remains the same, but the rest have changed along their respective dims

# %%
#more efficient way rather than to use for loops is use torch.tril
#as an egs
torch.manual_seed(42)
a = torch.tril(torch.ones(3, 3))
b = torch.randint(0, 10, (3, 2)).float()
c = a @ b
print('a', a)
print('b', b)
print('c', c)
# Out:
# a tensor([[1., 0., 0.],
#         [1., 1., 0.],
#         [1., 1., 1.]])
# b tensor([[2., 7.],
#         [6., 4.],
#         [6., 5.]])
# c tensor([[ 2.,  7.],
#         [ 8., 11.],
#         [14., 16.]])

# %%
#so we see that we get the same addition of past vectors into the current one as before, now we 
#just need to take its mean

# %%
torch.manual_seed(42)
a = torch.tril(torch.ones(3, 3)) / torch.sum(a, dim=1, keepdim=True)
b = torch.randint(0, 10, (3, 2)).float()
c = a @ b
print('a', a)
print('b', b)
print('c', c)
# Out:
# a tensor([[1.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000],
#         [0.3333, 0.3333, 0.3333]])
# b tensor([[2., 7.],
#         [6., 4.],
#         [6., 5.]])
# c tensor([[2.0000, 7.0000],
#         [4.0000, 5.5000],
#         [4.6667, 5.3333]])

# %%
#so its the same as before, but obtained much more efficiently, however, the way the attention mechanism
#is implemented itself is not that good, now making the same egs more efficient

# %%
torch.manual_seed(1337)
wei = torch.tril(torch.ones((T, T)))
wei /= torch.sum(wei, dim=1, keepdim=True)
xbow2 = wei @ x   # (T, T) @ (B, T, C) ---> (B, T, T) @ (B, T, C) after broadcasting which inturn
#gives (B, T, C) as the dim of xbow2
xbow2  #the same result
# Out:
# tensor([[[ 0.1808, -0.0700],
#          [-0.0894, -0.4926],
#          [ 0.1490, -0.3199],
#          [ 0.3504, -0.2238],
#          [ 0.3525,  0.0545],
#          [ 0.0688, -0.0396],
#          [ 0.0927, -0.0682],
#          [-0.0341,  0.1332]],
#
#         [[ 1.3488, -0.1396],
#          [ 0.8173,  0.4127],
#          [-0.1342,  0.4395],
#          [ 0.2711,  0.4774],
#          [ 0.2421,  0.0694],
#          [ 0.0084,  0.0020],
#          [ 0.0712, -0.1128],
#          [ 0.2527,  0.2149]],
#
#         [[-0.6631, -0.2513],
#          [ 0.1735, -0.0649],
#          [ 0.1685,  0.3348],
#          [-0.1621,  0.1765],
#          [-0.2312, -0.0436],
#          [-0.1015, -0.2855],
#          [-0.2593, -0.1630],
#          [-0.3015, -0.2293]],
#
#         [[ 1.6455, -0.8030],
#          [ 1.4985, -0.5395],
#          [ 0.4954,  0.3420],
#          [ 1.0623, -0.1802],
#          [ 1.1401, -0.4462],
#          [ 1.0870, -0.4071],
#          [ 1.0430, -0.1299],
#          [ 1.1138, -0.1641]]])

# %%
#the same thing could also be done using softmax
torch.manual_seed(1337)
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)

tril = torch.tril(torch.ones(T, T))
wei = torch.zeros((T, T))
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=1)
out = wei @ x
x
# Out:
# tensor([[[ 0.1808, -0.0700, -0.3596,  ..., -0.8016,  1.5236,  2.5086],
#          [-0.6631, -0.2513,  1.0101,  ...,  1.5333,  1.6097, -0.4032],
#          [-0.8345,  0.5978, -0.0514,  ..., -0.4370, -1.0012, -0.4094],
#          ...,
#          [-0.8961,  0.0662, -0.0563,  ...,  2.1382,  0.5114,  1.2191],
#          [ 0.1910, -0.3425,  1.7955,  ...,  0.3699, -0.5556, -0.3983],
#          [-0.5819, -0.2208,  0.0135,  ..., -1.9079, -0.5276,  1.0807]],
#
#         [[ 0.4562, -1.0917, -0.8207,  ...,  0.0512, -0.6576, -2.5729],
#          [ 0.0210,  1.0060, -1.2492,  ...,  0.7859, -1.1501,  1.3132],
#          [ 2.2007, -0.2195,  0.5427,  ..., -0.6445,  1.0834, -0.7995],
#          ...,
#          [ 0.3091,  1.1661, -2.1821,  ...,  0.6151,  0.6763,  0.6228],
#          [ 0.0943, -0.3156,  0.7850,  ..., -1.5735,  1.3876,  0.7251],
#          [ 0.6455, -0.3313, -1.0390,  ...,  0.0895, -0.3748, -0.4781]],
#
#         [[-0.6067,  1.8328,  0.2931,  ...,  1.0041,  0.8656,  0.1688],
#          [-0.2352, -0.2586,  0.0131,  ...,  0.6690,  0.7535, -0.5359],
#          [-1.0277,  0.5347, -0.7958,  ...,  1.0711,  0.4901, -0.4876],
#          ...,
#          [-0.6896, -0.7080, -0.3152,  ..., -2.0662, -1.1418, -0.1391],
#          [ 1.0827,  1.1522,  0.5198,  ...,  0.4970,  0.0585,  0.1033],
#          [ 0.0720,  1.1080,  0.7293,  ...,  0.3967, -0.9755,  0.5122]],
#
#         [[ 0.3330,  1.0995,  0.4034,  ...,  1.6634, -0.4718,  0.5857],
#          [-0.9579,  0.9435, -2.1992,  ..., -0.7296,  0.1653, -0.3390],
#          [ 1.5416,  1.0231,  1.3392,  ..., -0.0433, -0.2505, -0.7493],
#          ...,
#          [ 0.7450,  0.7170,  1.2668,  ...,  1.9359,  2.0350,  2.0187],
#          [ 0.0323, -0.6337,  0.2938,  ..., -0.3297, -0.0192,  0.9225],
#          [ 0.9187,  0.2998,  0.6106,  ...,  0.8282, -0.4826,  1.8330]]])

# %%
out  #the vals are slightly different, but doing it with just tril and the mean approach yields
#the exact results
# Out:
# tensor([[[ 1.8077e-01, -6.9988e-02, -3.5962e-01,  ..., -8.0164e-01,
#            1.5236e+00,  2.5086e+00],
#          [-2.4116e-01, -1.6063e-01,  3.2526e-01,  ...,  3.6581e-01,
#            1.5667e+00,  1.0527e+00],
#          [-4.3893e-01,  9.2179e-02,  1.9971e-01,  ...,  9.8210e-02,
#            7.1071e-01,  5.6531e-01],
#          ...,
#          [-9.8921e-01,  1.3417e-01,  2.8014e-01,  ...,  3.4950e-01,
#            6.1414e-01,  1.2510e-01],
#          [-8.2062e-01,  6.6077e-02,  4.9662e-01,  ...,  3.5242e-01,
#            4.4703e-01,  5.0332e-02],
#          [-7.9077e-01,  3.0213e-02,  4.3624e-01,  ...,  6.9874e-02,
#            3.2521e-01,  1.7912e-01]],
#
#         [[ 4.5618e-01, -1.0917e+00, -8.2073e-01,  ...,  5.1187e-02,
#           -6.5764e-01, -2.5729e+00],
#          [ 2.3859e-01, -4.2831e-02, -1.0349e+00,  ...,  4.1852e-01,
#           -9.0388e-01, -6.2984e-01],
#          [ 8.9262e-01, -1.0170e-01, -5.0905e-01,  ...,  6.4184e-02,
#           -2.4146e-01, -6.8638e-01],
#          ...,
#          [ 5.6778e-01,  3.5322e-01, -2.6951e-01,  ...,  2.4809e-01,
#           -5.0422e-02, -9.0907e-02],
#          [ 5.0014e-01,  2.5768e-01, -1.1887e-01,  ..., -1.2143e-02,
#            1.5501e-01,  2.5669e-02],
#          [ 5.1830e-01,  1.8405e-01, -2.3389e-01,  ...,  5.5685e-04,
#            8.8793e-02, -3.7308e-02]],
#
#         [[-6.0669e-01,  1.8328e+00,  2.9308e-01,  ...,  1.0041e+00,
#            8.6564e-01,  1.6879e-01],
#          [-4.2097e-01,  7.8707e-01,  1.5309e-01,  ...,  8.3654e-01,
#            8.0955e-01, -1.8358e-01],
#          [-6.2322e-01,  7.0294e-01, -1.6321e-01,  ...,  9.1471e-01,
#            7.0306e-01, -2.8491e-01],
#          ...,
#          [-3.3422e-01, -8.5831e-02,  2.4132e-01,  ...,  2.3987e-01,
#            1.5860e-02, -2.0914e-04],
#          [-1.3180e-01,  9.1034e-02,  2.8111e-01,  ...,  2.7661e-01,
#            2.1950e-02,  1.4572e-02],
#          [-1.0633e-01,  2.1815e-01,  3.3713e-01,  ...,  2.9162e-01,
#           -1.0273e-01,  7.6774e-02]],
#
#         [[ 3.3299e-01,  1.0995e+00,  4.0335e-01,  ...,  1.6634e+00,
#           -4.7180e-01,  5.8567e-01],
#          [-3.1246e-01,  1.0215e+00, -8.9794e-01,  ...,  4.6688e-01,
#           -1.5327e-01,  1.2333e-01],
#          [ 3.0558e-01,  1.0220e+00, -1.5221e-01,  ...,  2.9682e-01,
#           -1.8568e-01, -1.6754e-01],
#          ...,
#          [ 4.9366e-01,  5.0418e-01,  1.2845e-01,  ...,  1.5478e-01,
#            6.3110e-01, -1.5307e-01],
#          [ 4.2775e-01,  3.4162e-01,  1.5207e-01,  ...,  8.5563e-02,
#            5.3821e-01,  5.8160e-04],
#          [ 4.8912e-01,  3.3639e-01,  2.0939e-01,  ...,  1.7840e-01,
#            4.1060e-01,  2.2963e-01]]])

# %%
#now lets look at a single head of attention, where the query and key vectors of the tokens
#are of a certain type, we implement several heads where each one asks a different set questions, and that
#is learnt from training

#single head of attention
torch.manual_seed(1337)
head_size = 16
B, T, C = 4, 8, 32  #here the C is the embedding dimension
x = torch.randn(B, T, C)

key = nn.Linear(C, head_size, bias=False) #instead of defining the weights, we use the nn.Linear, 
#where the weights here are of (head_size, embedding_dim), no biases needed here
query = nn.Linear(C, head_size, bias=False)
value = nn.Linear(C, head_size, bias=False)  #the value martrix, which is of (emb_dim, head_size), 
#its represented through a linear layer

k = key(x)  # (B, T, C) --> (B, T, head_size)
q = query(x)  # (B, T, C) --> (B, T, head_size)
v = value(x) # (B, T, C) --> (B, T, head_size)

wei = q @ k.transpose(-2, -1) / (head_size) ** 0.5  # (B, T, head_size) @ (B, head_size, T)  ---> (B, T, T)
#also as per the paper, the weights are scaled by the sqrt of the head_size, this is done to ensure that the
#numerical stability is maintained, as the dot product of the query and key vectors can be very large, and
#also as we want the wei's var to be close to 1 so that when its passed into the softmax func
#it is fairly diffused 

tril = torch.tril(torch.ones(T, T))  
#now masking the upper triangular part of the matrix, as the tokens in the future should not be
#considered when calculating the attention for the current token
wei = wei.masked_fill(tril == 0, float('-inf'))  #this is the decoder block, where we
#mask the future tokens for a given token
#now passing each row of the wei matrix through the softmax function, which means that
#we pass each of the key.query vector for each token through the softmax function
wei = F.softmax(wei, dim=2)  # (B, T, T)

#now the matrices within the wei tensor that we have is the *attention grid*, where the affinity
#of each token with its prev neighbours is calculated, and this is done for each token in the batch

out = wei @ v  # (B, T, T) @ (B, T, head_size) ---> (B, T, head_size)
#instead of matr mult the raw xs with the attention grid, we do it with the value vectors we obtain
#by matr mul the value matrix with x

# %% [markdown]
# ### a very interesting way to think about key, query, value vectors of a token are: <br>
# > key: what do i contain <br>
# > query: what am i looking for <br>
# > value: if you find me interesting, here is what i will communicate with you

# %%
out.shape
# Out:
# torch.Size([4, 8, 16])

# %%
wei
# Out:
# tensor([[[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3966, 0.6034, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3069, 0.2892, 0.4039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3233, 0.2175, 0.2443, 0.2149, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.1479, 0.2034, 0.1663, 0.1455, 0.3369, 0.0000, 0.0000, 0.0000],
#          [0.1259, 0.2490, 0.1324, 0.1062, 0.3141, 0.0724, 0.0000, 0.0000],
#          [0.1598, 0.1990, 0.1140, 0.1125, 0.1418, 0.1669, 0.1061, 0.0000],
#          [0.0845, 0.1197, 0.1078, 0.1537, 0.1086, 0.1146, 0.1558, 0.1553]],
#
#         [[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.4016, 0.5984, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3365, 0.2271, 0.4364, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3019, 0.2060, 0.2899, 0.2022, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.1058, 0.1700, 0.1530, 0.3451, 0.2261, 0.0000, 0.0000, 0.0000],
#          [0.1526, 0.1645, 0.1357, 0.2684, 0.1919, 0.0869, 0.0000, 0.0000],
#          [0.1103, 0.1711, 0.0761, 0.1654, 0.1667, 0.1643, 0.1461, 0.0000],
#          [0.1770, 0.1063, 0.1198, 0.0943, 0.1697, 0.1205, 0.1052, 0.1073]],
#
#         [[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.4955, 0.5045, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.2861, 0.3657, 0.3483, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.1242, 0.3939, 0.1981, 0.2838, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3531, 0.1668, 0.1768, 0.1813, 0.1220, 0.0000, 0.0000, 0.0000],
#          [0.1553, 0.1779, 0.1492, 0.1539, 0.1723, 0.1914, 0.0000, 0.0000],
#          [0.0722, 0.1255, 0.1119, 0.1896, 0.1537, 0.1918, 0.1552, 0.0000],
#          [0.1344, 0.1368, 0.0970, 0.1395, 0.1292, 0.1304, 0.0790, 0.1535]],
#
#         [[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.5351, 0.4649, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3776, 0.4907, 0.1317, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.3079, 0.2849, 0.2206, 0.1865, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.2074, 0.2611, 0.1368, 0.2071, 0.1876, 0.0000, 0.0000, 0.0000],
#          [0.1733, 0.3004, 0.0656, 0.1682, 0.1669, 0.1255, 0.0000, 0.0000],
#          [0.1216, 0.1213, 0.1416, 0.1119, 0.1439, 0.2213, 0.1383, 0.0000],
#          [0.0925, 0.1598, 0.0945, 0.1355, 0.1356, 0.1086, 0.1185, 0.1548]]],
#        grad_fn=<SoftmaxBackward0>)

# %%
#now the thing is that we have multiple blocks of attention and MLPs now, and now the neural 
#net becomes very deep, and hence we suffer from a problem of vanishing gradients, and to solve this
#we use residual connections

# %%
#another thing we do is apply layer norm to each of the tokens after the attention and the MLP
#blocks

class LayerNorm1d:
    def __init__(self, dim, eps=1e-5):
        self.eps = eps
        self.gamma = torch.ones(dim)
        self.beta = torch.zeros(dim)

    def __call__(self, x):  #x is the samples of the batch 
        xmean = x.mean(1, keepdim=True)
        xvar = x.var(1, keepdim=True)
        self.out = self.gamma * (x - xmean/torch.sqrt(xvar + self.eps)) + self.beta
        return self.out
    
    def parameters(self):
        return [self.gamma, self.beta]
    
torch.manual_seed(1337)
layernorm = LayerNorm1d(100)
x = torch.randn(32, 100)
x = layernorm(x)
x.shape
# Out:
# torch.Size([32, 100])

# %%
torch.mean(x, dim=1), torch.std(x, dim=1)
#very close to 0 and 1, which is what we want
# Out:
# (tensor([ 0.0019,  0.0059,  0.0205, -0.0010, -0.0139,  0.0004, -0.0112,  0.0028,
#           0.0044, -0.0065,  0.0051,  0.0020,  0.0052, -0.0003, -0.0110, -0.0020,
#          -0.0007, -0.0108,  0.0005,  0.0138,  0.0047,  0.0013, -0.0010,  0.0037,
#          -0.0012, -0.0001, -0.0006,  0.0072,  0.0298,  0.0096,  0.0009, -0.0053]),
#  tensor([1.0476, 1.0915, 0.9288, 1.0249, 1.1154, 0.9816, 1.1236, 0.9649, 1.0968,
#          0.9639, 0.9587, 1.0506, 0.9354, 1.0164, 0.9489, 0.9367, 0.9625, 0.8671,
#          0.9902, 0.9383, 1.0853, 0.9343, 0.9951, 0.8625, 0.9540, 0.9937, 0.9887,
#          0.8877, 1.1251, 1.0934, 1.0617, 1.0448]))

# %%
#and in our case, when we get the output from any of the blocks, we pass it through the layer norm
#layer to normalise it for each of the token vectors, however here we utilise the more modern approach
#which is pre layer norm where the layer norm is applied before the attention and the MLP blocks

# %%
#we also add dropout layers after the individual attention grid is obtained and also after 
#the MLP block and also after the multi head attention block's output is obtained, its done 
#to prevent overfitting

#what dropout essentially does is, during training, every forward and backward pass randomly
#lets the activations of neurons in the layer on which it was applied be 0, effectively dropping those
#and what this does is since the mask of the neurons being dropped off changes every forward and back
#pass, it ends up simulating training on an ensemble of networks, and hence the network becomes more
#robust and generalises better, so during inference when all the neurons are active, the network
#is able to generalise better, preventing overfitting

# %%
#in cross headed attention, the queries are still generated by the part of transformer
#to which the conversion has to be done to say english, and the keys and values are generated
#by the part of the transformer which has to convert the input to say french, in that part of the
#transformer, there is no decoder block, hence all parts of the context window can talk to each
#other no matter where they are placed, and once thats done, they move on to the primary 
#part of the transformer where they generate keys and vals and the queries are generated by the
#part of the transformer which has to convert the input to say english. This approach is also known
#as encoder-decoder type of attention

# %%
#this type of training is known as the pretraining phase, where the model is trained on a large
#corpus of text, and then fine tuned on a smaller dataset, and this is done to prevent overfitting
#but the other part of the training is where fine tuning occurs where after the pretraning phase
#the model just behaves like a document completer, in case of latest versions of GPT, it would just
#babble out the internet, cause thats what it was really trained on, then in the fine tuning phase
#a labeller would group the qs and the ans so as to say, so that the GPT actually behaves like
#a chatbot, here approached like RLHF which is reinforcement learning from human feedback is implemented

# %%
#also put the entire loop part of bigram.py in main as
#when its called for inference in generation.py, we dont
#want the training process to start again when we call the 
#model class
